# %% [markdown]
# Data can be found: https://data-seattlecitygis.opendata.arcgis.com/search?collection=Dataset&modified=2021-01-01%2C2021-10-13

# %%
import geopandas as gpd

# %%
gpd.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
world = gpd.read_file(
    gpd.datasets.get_path('naturalearth_lowres')
)
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
seattle_zoning_2035 = gpd.read_file('Future_Land_Use__2035.shp')
seattle_zoning_2035.head()
# Out:
#    OBJECTID                             FLUM  ORDINANCE     ADOPTED  \
# 0         1                         Cemetery     125173  2016-10-17
# 1         2                Hub Urban Village     125173  2016-10-17
# 2         3                 Industrial Areas     125173  2016-10-17
# 3         4               Major Institutions     125173  2016-10-17
# 4         5  Manufacturing Industrial Center     125173  2016-10-17
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.33419 47.70871, -122.3343...
# 1  MULTIPOLYGON (((-122.30786 47.58930, -122.3074...
# 2  MULTIPOLYGON (((-122.33389 47.64684, -122.3339...
# 3  MULTIPOLYGON (((-122.28757 47.65796, -122.2875...
# 4  MULTIPOLYGON (((-122.30779 47.53173, -122.3084...

# %%
education_centers = gpd.read_file('data/Environmental_Education_Centers.shp')
education_centers
# Out:
#    OBJECTID  ID                 NAME                      ADDRESS  \
# 0         1   8           Alki Beach                         None
# 1         2   9         Ravenna Park                         None
# 2         3  10  Golden Gardens Park                         None
# 3         4   5          Seward Park  5500 Lake Washington Blvd S
# 4         5   6    Woodland Park Zoo            700 North 50th St
# 5         6   7       Lakeridge Park                         None
# 6         7   3            Camp Long                 5200 35th SW
# 7         8   4     Seattle Aquarium             1483 Alaskan Way
# 8         9   1       Discovery Park        3801 W Government Way
# 9        10   2         Carkeek Park     950 NW Carkeek Park Road
#
#        COORDINATO     PHONE     SITE SE_ANNO_CA PMAID LINK_1 LINK_2 ALT_NAME  \
# 0            None      None  Program       None   445   None   None     None
# 1            None      None  Program       None   391   None   None     None
# ...
